# %%
import datetime
import calendar
import win32com.client as win32
import openpyxl
import pandas as pd
import ctypes
import win32com
import time
import shutil
import warnings
import os
from pathlib import Path
from openpyxl.styles import Font, NamedStyle, Alignment
pip install auto-py-to-exe
auto-py-to-exe



start_time = time.time()
reak = str(Path.cwd() / f'reak/Гуру тестирования 3 кв.23.xlsx') #таблица
name_s = os.path.basename(reak)
bdzh = str(Path.cwd() / f'bdzh/Бейджи.xlsx') #таблица бейджи
name_s = os.path.basename(bdzh)
shabl = str(Path.cwd() / f'shabl/Шаблон.xlsx') #№3 таблица (шаблон для формирования результата)
itog = str(Path.cwd() /f"itog/Итоги гуру тестирования.xlsx")  #сформированный файл

excel = win32.Dispatch("Excel.Application") #интеграция
ex = True  # Поставить False для итогового варианта
excel.Visible = ex
excel.DisplayAlerts = ex
excel.ScreenUpdating = ex

print('загрузка данных')

#чтение таблицы 1.1 
df1 = pd.read_excel(reak, 'Дизайн в друге')

df1.fillna("-", inplace=True) 
df1['ФИО'] = df1['ФИО'].astype(str)

print('DF1  - Done')
lst_t1 = df1['ФИО'].tolist()
print("список ТН - Done") 
df1 = df1.set_index('ФИО') 


#чтение таблицы 1.2 
df2 = pd.read_excel(reak, 'Функционал в приложении ОТР')

df2.fillna("-", inplace=True) 
df2['ФИО'] = df2['ФИО'].astype(str)

print('DF2  - Done')
lst_t2 = df2['ФИО'].tolist()
print("список ТН - Done") 
df2 = df2.set_index('ФИО') 


#чтение таблицы 1.3 
df3 = pd.read_excel(reak, 'Функционал в Друге')

df3.fillna("-", inplace=True) 
df3['ФИО'] = df3['ФИО'].astype(str)

print('DF3  - Done')
lst_t3 = df3['ФИО'].tolist()
print("список ТН - Done") 
df3 = df3.set_index('ФИО') 

#чтение таблицы 1.4 
df4 = pd.read_excel(reak, 'Демо-версия игры')

df4.fillna("-", inplace=True) 
df4['ФИО'] = df4['ФИО'].astype(str)

print('DF4  - Done')
lst_t4 = df4['ФИО'].tolist()
print("список ТН - Done") 
df4 = df4.set_index('ФИО') 


#чтение таблицы 1.5 
df5 = pd.read_excel(reak, 'lovemark')

df5.fillna("-", inplace=True) 
df5['ФИО'] = df5['ФИО'].astype(str)

print('DF5  - Done')
lst_t5 = df5['ФИО'].tolist()
print("список ТН - Done") 
df5 = df5.set_index('ФИО') 


#чтение таблицы 1.6 
df6 = pd.read_excel(reak, 'Редактор текста в сберЧате')

df6.fillna("-", inplace=True) 
df6['ФИО'] = df6['ФИО'].astype(str)

print('DF6  - Done')
lst_t6 = df6['ФИО'].tolist()
print("список ТН - Done") 
df6 = df6.set_index('ФИО') 


#чтение таблицы 1.7 
df7 = pd.read_excel(reak, 'Опрос по фроду')

df7.fillna("-", inplace=True) 
df7['ФИО'] = df7['ФИО'].astype(str)

print('DF7  - Done')
lst_t7 = df7['ФИО'].tolist()
print("список ТН - Done") 
df7 = df7.set_index('ФИО') 


#чтение таблицы 1.8 
df8 = pd.read_excel(reak, 'Оценка продуктов сберюзера')

df8.fillna("-", inplace=True) 
df8['ФИО'] = df8['ФИО'].astype(str)

print('DF8  - Done')
lst_t8 = df8['ФИО'].tolist()
print("список ТН - Done") 
df8 = df8.set_index('ФИО') 



#чтение таблицы 1.9 
df9 = pd.read_excel(reak, 'Сделаем Друг лучше')

df9.fillna("-", inplace=True) 
df9['ФИО'] = df9['ФИО'].astype(str)

print('DF9  - Done')
lst_t9 = df9['ФИО'].tolist()
print("список ТН - Done") 
df9 = df9.set_index('ФИО')


#чтение таблицы 1.10 
#df10 = pd.read_excel(reak, 'Конкурсы ВАС')

#df10.fillna("-", inplace=True) 
#df10['ФИО'] = df10['ФИО'].astype(str)

#print('DF10  - Done')
#lst_t10 = df10['ФИО'].tolist()
#print("список ТН - Done") 
#df10 = df10.set_index('ФИО')


#чтение таблицы 1.11 
#df11 = pd.read_excel(reak, 'Функционал ленты ДРУГа')

#df11.fillna("-", inplace=True) 
#df11['ФИО'] = df11['ФИО'].astype(str)
#
#print('DF11  - Done')
#lst_t11 = df11['ФИО'].tolist()
#print("список ТН - Done") 
#df11 = df11.set_index('ФИО')


#чтение таблицы 1.12 
#df12 = pd.read_excel(reak, 'Гемба')

#df12.fillna("-", inplace=True) 
#df12['ФИО'] = df12['ФИО'].astype(str)

#print('DF12  - Done')
#lst_t12 = df12['ФИО'].tolist()
#print("список ТН - Done") 
#df12 = df12.set_index('ФИО')

#чтение таблицы 1.13 
#df13 = pd.read_excel(reak, 'Поиск в ДРУГе')

#df13.fillna("-", inplace=True) 
#df13['ФИО'] = df13['ФИО'].astype(str)

#print('DF13  - Done')
#lst_t13 = df13['ФИО'].tolist()
#print("список ТН - Done") 
#df13 = df13.set_index('ФИО')


#чтение таблицы 1.14 
#df14 = pd.read_excel(reakd, 'Речевой тренажер в ВСП')

#df14.fillna("-", inplace=True) 
#df14['ФИО'] = df14['ФИО'].astype(str)

#print('DF14  - Done')
#lst_t14 = df14['ФИО'].tolist()
#print("список ТН - Done") 
#df14 = df14.set_index('ФИО')


#чтение таблицы 1.15 
#df15 = pd.read_excel(reakd, 'Мой HR-партнер')

#df15.fillna("-", inplace=True) 
#df15['ФИО'] = df15['ФИО'].astype(str)

#print('DF15  - Done')
#lst_t15 = df15['ФИО'].tolist()
#print("список ТН - Done") 
#df15 = df15.set_index('ФИО')


#чтение таблицы 1.16 
#df16 = pd.read_excel(reakd, 'Мой грейд')

#df16.fillna("-", inplace=True) 
#df16['ФИО'] = df16['ФИО'].astype(str)

#print('DF16  - Done')
#lst_t16 = df16['ФИО'].tolist()
#print("список ТН - Done") 
#df16 = df16.set_index('ФИО')


#чтение таблицы 1.17 
#df17 = pd.read_excel(reakd, 'SberJazz')

#df17.fillna("-", inplace=True) 
#df17['ФИО'] = df17['ФИО'].astype(str)

#print('DF17  - Done')
#lst_t17 = df17['ФИО'].tolist()
#print("список ТН - Done") 
#df17 = df17.set_index('ФИО')


#чтение таблицы 18 
df18 = pd.read_excel(bdzh, 'Лист1')

df18.fillna("-", inplace=True) 
df18['ФИО'] = df18['ФИО'].astype(str)

print('DF18  - Done')
lst_t18 = df18['ФИО'].tolist()
print("список ТН - Done") 
df18 = df18.set_index('ФИО')

print('download shablon')
start_time_2 = time.time()  # время запуска
wb = openpyxl.load_workbook(shabl)

ws = wb.active
n = 0
sheets = wb.sheetnames
wsa = wb[sheets[n]]
# print(wsa)
rows = wsa.max_row 
cols = wsa.max_column 
# wsa.sheet_properties.tabColor = '66FF00'
print('Запускается перебор строк')

#выгрузка данных в шаблон

for i in range(2, rows+1):

    if wsa.cell(row=i, column=1).value in lst_t1:

        wsa.cell(row=i, column=12).value =1
                
    elif wsa.cell(row=i, column=1).value not in lst_t1:
        wsa.cell(row=i, column=12).value =0

   
    if wsa.cell(row=i, column=1).value in lst_t2:

        wsa.cell(row=i, column=13).value =1
                
    elif wsa.cell(row=i, column=1).value not in lst_t2:
        wsa.cell(row=i, column=13).value =0 
        
for i in range(2, rows+1):
    
    if wsa.cell(row=i, column=1).value in lst_t3:

        wsa.cell(row=i, column=14).value =1
                
    elif wsa.cell(row=i, column=1).value not in lst_t3:
        wsa.cell(row=i, column=14).value =0
        
for i in range(2, rows+1):
        
    if wsa.cell(row=i, column=1).value in lst_t4:

        wsa.cell(row=i, column=15).value =1
                
    elif wsa.cell(row=i, column=1).value not in lst_t4:
        wsa.cell(row=i, column=15).value =0 
        
for i in range(2, rows+1):
        
    if wsa.cell(row=i, column=1).value in lst_t5:

        wsa.cell(row=i, column=16).value =1
                
    elif wsa.cell(row=i, column=1).value not in lst_t5:
        wsa.cell(row=i, column=16).value =0
        
for i in range(2, rows+1):
        
    if wsa.cell(row=i, column=1).value in lst_t6:

        wsa.cell(row=i, column=17).value =1
                
    elif wsa.cell(row=i, column=1).value not in lst_t6:
        wsa.cell(row=i, column=17).value =0 
        
for i in range(2, rows+1):
        
    if wsa.cell(row=i, column=1).value in lst_t7:

        wsa.cell(row=i, column=18).value =1
                
    elif wsa.cell(row=i, column=1).value not in lst_t7:
        wsa.cell(row=i, column=18).value =0
        
        
for i in range(2, rows+1):
        
    if wsa.cell(row=i, column=1).value in lst_t8:

        wsa.cell(row=i, column=19).value =1
                
    elif wsa.cell(row=i, column=1).value not in lst_t8:
        wsa.cell(row=i, column=19).value =0
        
        
        
for i in range(2, rows+1):
        
    if wsa.cell(row=i, column=1).value in lst_t9:

        wsa.cell(row=i, column=20).value =1
                
    elif wsa.cell(row=i, column=1).value not in lst_t9:
        wsa.cell(row=i, column=20).value =0
        
        
        
#for i in range(2, rows+1):
        
    #if wsa.cell(row=i, column=1).value in lst_t10:

        #wsa.cell(row=i, column=21).value =1
                
    #elif wsa.cell(row=i, column=1).value not in lst_t10:
        #wsa.cell(row=i, column=21).value =0
        
#for i in range(2, rows+1):
        
    #if wsa.cell(row=i, column=1).value in lst_t11:

        #wsa.cell(row=i, column=22).value =1
                
    #elif wsa.cell(row=i, column=1).value not in lst_t11:
        #wsa.cell(row=i, column=22).value =0
        
#for i in range(2, rows+1):
        
   # if wsa.cell(row=i, column=1).value in lst_t12:

        #wsa.cell(row=i, column=23).value =1
                
   # elif wsa.cell(row=i, column=1).value not in lst_t12:
       # wsa.cell(row=i, column=23).value =0

        
#for i in range(2, rows+1):
        
   # if wsa.cell(row=i, column=1).value in lst_t13:
#
      #  wsa.cell(row=i, column=24).value =1
                
    #elif wsa.cell(row=i, column=1).value not in lst_t13:
        #wsa.cell(row=i, column=24).value =0
        
#for i in range(2, rows+1):
        
  #  if wsa.cell(row=i, column=1).value in lst_t14:

      #  wsa.cell(row=i, column=38).value =1
                
  #  elif wsa.cell(row=i, column=1).value not in lst_t14:
   #     wsa.cell(row=i, column=38).value =0
        
#for i in range(2, rows+1):
        
   # if wsa.cell(row=i, column=1).value in lst_t15:

    #    wsa.cell(row=i, column=39).value =1
                
   # elif wsa.cell(row=i, column=1).value not in lst_t15:
  #      wsa.cell(row=i, column=39).value =0
        
#for i in range(2, rows+1):
        
  #  if wsa.cell(row=i, column=1).value in lst_t16:

   #     wsa.cell(row=i, column=40).value =1
                
   # elif wsa.cell(row=i, column=1).value not in lst_t16:
     #   wsa.cell(row=i, column=40).value =0
        
#for i in range(2, rows+1):
        
    #if wsa.cell(row=i, column=1).value in lst_t17:

     #   wsa.cell(row=i, column=41).value =1
                
   # elif wsa.cell(row=i, column=1).value not in lst_t17:
     #   wsa.cell(row=i, column=41).value =0
        
for i in range(2, rows+1):
        
    if wsa.cell(row=i, column=1).value in lst_t18:

        wsa.cell(row=i, column=11).value ="есть"
                
    elif wsa.cell(row=i, column=1).value not in lst_t18:
        wsa.cell(row=i, column=11).value ="нет"

for i in range(2, rows+1):
    
    if wsa.cell(row=i, column=1).value!="":
        
       # a=wsa.cell(row=i, column=25).value
       # b=wsa.cell(row=i, column=26).value
       # c=wsa.cell(row=i, column=27).value
       # d=wsa.cell(row=i, column=28).value
       # g=wsa.cell(row=i, column=29).value
      #  f=wsa.cell(row=i, column=10).value
      #  k=wsa.cell(row=i, column=11).value
        l=wsa.cell(row=i, column=12).value
        m=wsa.cell(row=i, column=13).value
        n=wsa.cell(row=i, column=14).value
        o=wsa.cell(row=i, column=15).value
        p=wsa.cell(row=i, column=16).value
        r=wsa.cell(row=i, column=17).value
        s=wsa.cell(row=i, column=18).value
        t=wsa.cell(row=i, column=19).value
        u=wsa.cell(row=i, column=20).value
       # f=wsa.cell(row=i, column=21).value
       # k=wsa.cell(row=i, column=22).value
       # a=wsa.cell(row=i, column=23).value
      #  b=wsa.cell(row=i, column=24).value
        
        
        wsa.cell(row=i, column=21).value = l+m+n+o+p+r+s+t+u

print('переменные')

wb.save(itog)
ext = True
excel.Visible = ext
excel.DisplayAlerts = ext
excel.ScreenUpdating = ext

print(f'save - {itog}')

# wb = excel.Workbooks.Open(shabl
# Out:
#   File "<ipython-input-4-f4f46362d6b9>", line 14
#     import pip install auto-py-to-exe
#                      ^
# SyntaxError: invalid syntax
